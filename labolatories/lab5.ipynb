# %%
print('test')
# Out:
# test

# %%
import numpy as np

maxiter = 100
def julia(z, c):
    for n in range(maxiter):
        if np.abs(z) > 4:
            return n-1
        z = z*z + c
    return maxiter
julia(0.4+0.5j, 0.6+0.7j)
# Out:
# 3

# %%
v = np.array([ [( julia(r+i*1j, 0.05+0.665j) ) for i in np.arange(-0.5, 0.5, 0.01)] for r in np.arange(-1,1, 0.02)])
v
# Out:
# array([[2, 2, 2, ..., 5, 5, 6],
#        [2, 2, 2, ..., 5, 6, 6],
#        [2, 2, 2, ..., 6, 6, 7],
#        ...,
#        [9, 8, 7, ..., 2, 2, 2],
#        [7, 7, 6, ..., 2, 2, 2],
#        [6, 6, 6, ..., 2, 2, 2]])

# %%
from matplotlib import cm

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(v, cmap=cm.get_cmap('jet', 100), interpolation='bessel')

# %%
#%matplotlib qt

v = []
for s in np.arange(-0.05, -0.08, -0.002):
    print(f"Counting for s={s}")
    v.append( np.array([ [ ( julia(r + i*1j, s + 0.665j) ) for i in np.arange(-0.5, 0.5, 0.01)] for r in np.arange(-1,1, 0.02)]) )


plt.figure(figsize=(10,8))
p = None
for vec in v:
    if p is None:
        # p = plt.imshow(vec, cmap=cm.get_cmap('jet_r', 100), interpolation='bessel')
        p = plt.imshow(vec, cmap=cm.get_cmap('jet_r', 100))
    else:
        p.set_data(vec)
    plt.pause(0.01)
# Out:
# Counting for s=-0.05
# Counting for s=-0.052000000000000005
# Counting for s=-0.054000000000000006
# Counting for s=-0.05600000000000001
# Counting for s=-0.05800000000000001
# Counting for s=-0.06000000000000001
# Counting for s=-0.06200000000000001
# Counting for s=-0.06400000000000002
# Counting for s=-0.06600000000000002
# Counting for s=-0.06800000000000002
# Counting for s=-0.07000000000000002
# Counting for s=-0.07200000000000002
# Counting for s=-0.07400000000000002
# Counting for s=-0.07600000000000003
# Counting for s=-0.07800000000000003

# %%
import numpy as np
import matplotlib.pyplot as plt
eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))
plt.axes([0.425,0.025,0.55,0.95])
for i in range(24):
    index = np.random.randint(0,len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12,32)
    x,y = np.random.uniform(0,1,2)
    alpha = np.random.uniform(0.25,.75)
    c = "#{:02x}{:02x}{:02x}".format( *[int(np.random.uniform(0,255)) for _ in range(3) ] )
    plt.text(x, y, eq, ha='center', va='center', color=c, alpha=alpha,
             transform=plt.gca().transAxes, fontsize=size, clip_on=True)
plt.xticks([]), plt.yticks([])
# savefig('../figures/text_ex.png',dpi=48)
plt.show()

# %%
r = [np.random.triangular(1,5,10) for _ in range(100000)]
plt.hist(r, bins=50, rwidth=0.2)
# Out:
# (array([  99.,  290.,  484.,  646.,  834.,  974., 1139., 1302., 1474.,
#         1675., 1884., 2089., 2088., 2493., 2595., 2769., 3062., 3259.,
#         3402., 3481., 3705., 3831., 3903., 3877., 3718., 3396., 3440.,
#         3314., 3121., 2912., 2819., 2726., 2485., 2339., 2213., 2034.,
#         1900., 1814., 1610., 1519., 1344., 1218., 1083.,  970.,  792.,
#          660.,  536.,  350.,  242.,   90.]),
#  array([1.02175015, 1.20100592, 1.38026168, 1.55951745, 1.73877322,
#         1.91802898, 2.09728475, 2.27654052, 2.45579629, 2.63505205,
#         2.81430782, 2.99356359, 3.17281935, 3.35207512, 3.53133089,
#         3.71058665, 3.88984242, 4.06909819, 4.24835395, 4.42760972,
#         4.60686549, 4.78612126, 4.96537702, 5.14463279, 5.32388856,
#         5.50314432, 5.68240009, 5.86165586, 6.04091162, 6.22016739,
#         6.39942316, 6.57867892, 6.75793469, 6.93719046, 7.11644623,
#         7.29570199, 7.47495776, 7.65421353, 7.83346929, 8.01272506,
# ...

# %%
x = np.arange(0, 2*np.pi, 0.1)
plt.plot(x, np.sin(x), 'g:',x, np.cos(x))

# %%
x = np.arange(0, 2*np.pi, 0.1)
plt.plot(x, np.sin(x),'g:',  lw=5)
plt.plot(x, np.cos(x))
plt.plot(x, np.cos(2*x))
plt.xlabel("My x Axis $A_i^u$")
plt.title("Familiar MATLAB?")
# Out:
# Text(0.5, 1.0, 'Familiar MATLAB?')

# %%
# %matplotlib inline
f = plt.figure()
#ax = f.add_axes([0.1,0.05,0.8,0.9])
ax = f.subplots(1,2)
ax[0].plot(x, np.sin(x),'g:',  lw=5)
ax[1].plot(x, np.cos(x))
ax[0].set_xlabel("My Nice X Label in Subplot\nYou will get used to long labels?")
# Out:
# Text(0.5, 0, 'My Nice X Label in Subplot\nYou will get used to long labels?')

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,4)
plt.plot(x, np.sin(x))

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.ylim(C.min()*1.1,C.max()*1.1)
plt.yticks([-1, 0, +1],
[r'$-1$', r'$0$', r'$+1$'])
plt.show()
